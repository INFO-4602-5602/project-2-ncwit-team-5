# %%
#instruction
#everyone has their own part, do not edit others
#we will combine everything together at the end
#do not use the >| mark
#use the run cell in "Cell"
#GLHF

# %%
#Zening Li

# %%
#Zhixing Chang
import pandas as pd
df = pd.read_csv("NCWIT_DataV2_RawData.csv",sep=',', error_bad_lines=False, index_col=False, dtype='unicode')
#dashboard_df = pd.read_csv(p_file, )

df
# Out:
#      Record# CIP# Only                                 Major Program Name  \
# 0       1231   11.0100  CS and/or Eng Multiple Majors (data submitted ...
# 1       1232   11.0100  CS and/or Eng Multiple Majors (data submitted ...
# 2       1233   11.0100  CS and/or Eng Multiple Majors (data submitted ...
# 3       1234   11.0100  CS and/or Eng Multiple Majors (data submitted ...
# 4       1235   11.0100  CS and/or Eng Multiple Majors (data submitted ...
# 5       1236   11.0100  CS and/or Eng Multiple Majors (data submitted ...
# 6       1237   11.0100  CS and/or Eng Multiple Majors (data submitted ...
# 7       1498   11.0100                     Computer Science / Engineering
# 8       1499   11.0100                     Computer Science / Engineering
# 9       1500   11.0100                     Computer Science / Engineering
# 10      1501   11.0100                     Computer Science / Engineering
# 11      1502   11.0100                     Computer Science / Engineering
# ...

# %%
#Yifan Li

# %%
#Peng Yan
import pandas as pd
import numpy as np
import sys
import matplotlib.pylab as plt
# %matplotlib inline
import pylab as pl
from pandas import *

df = pd.read_csv("NCWIT_DataV2_RawData.csv")
#dashboard_df = pd.read_csv(p_file, )


df.hist(column="Institution", bins=10, figsize=(10,8), facecolor="steelblue", edgecolor="white")
pl.title("Frequency")
pl.xlabel("Institution")
pl.ylabel("Frequency")

df['School Year']=pd.to_datetime(df.School Year)
dfg= df.sort_values(by="School Year", ascending=True)

ax=dfg.plot(x = "School Year", y = ["Degree Level"],figsize=(20,10), grid=True,title="Change")

# Add axis labels 
ax.set_xlabel("School Year", fontsize=16)
ax.set_ylabel("Degree Level", fontsize=16)
plt.show()
# Out:
# C:\Users\Chenyan886\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-0adad1844bd1> in <module>()
#      18
#      19
# ---> 20 ax=df.plot(x = "School Year", y = ["Degree Level"],figsize=(20,10), grid=True,title="Change")
#      21
#      22 # Add axis labels
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
# ...

# %%
#import data
import numpy as np
import pandas as pd
web path = 'https://github.com/INFO-4602-5602/project-2-ncwit-team-5/blob/master/NCWIT_DataV2_RawData.csv'
